# %%
import numpy as np
import DataGeneration
import Visualization
from model import Regressors
from model import LowFrequencyTrends

# %%
T = 100
min_val = 10*2
max_val = 10*5
yt = DataGeneration.generate_continuous_data(T, min_val, max_val)

# %%
regressors = Regressors.find_time_series_regressors(yt, 0.32)
print(regressors.shape)
Visualization.plot_regressors(regressors, 10)
# Out:
# (17, 100)

# %%
Y, predictions = LowFrequencyTrends.find_trends(yt, 0.32)
Visualization.plot_data_and_prediction(T, yt, predictions)
