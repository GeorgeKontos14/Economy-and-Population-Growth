# %%
import numpy as np
import matplotlib.pyplot as plt
import DataGeneration
from model import Regressors
from model import LowFrequencyTrends

# %%
T = 100
min_val = 7*10**8
max_val = 10**10
filename = "generated.csv"
continuous = DataGeneration.generate_continuous_data(T, min_val, max_val)
#DataGeneration.plot_logarithm(T, continuous)
unbalanced = DataGeneration.generate_unbalanced_data(T, min_val, max_val, 0.01)
#DataGeneration.plot_logarithm(T, unbalanced)

# %%
data = DataGeneration.generate_multiple_series(T, 10, min_val, max_val, filename)
DataGeneration.plot_multiple_series(data)

# %%
read_data = DataGeneration.read_data(filename)
DataGeneration.plot_multiple_series(data)

# %%
y = data[0]
DataGeneration.plot_logarithm(T, y)
regressors = Regressors.find_time_series_regressors(y, 0.32)
Y, B = LowFrequencyTrends.find_coefficients(y, 0.32)
# Out:
# 17
# (32, 100)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[5], line 4
#       2 DataGeneration.plot_logarithm(T, y)
#       3 regressors = Regressors.find_time_series_regressors(y, 0.32)
# ----> 4 Y, B = LowFrequencyTrends.find_coefficients(y, 0.32)
#
# File c:\Users\konto\Documents\Economy-and-Population-Growth\model\LowFrequencyTrends.py:20, in find_coefficients(yi, cutoff)
#      18 print(len(Y_i))
#      19 print(X_i.shape)
# ---> 20 B, _, _, _ = np.linalg.lstsq(X_i.T, Y_i, rcond=None)
#      22 return Y_i, B
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\numpy\linalg\linalg.py:2297, in lstsq(a, b, rcond)
#    2295 m2, n_rhs = b.shape[-2:]
#    2296 if m != m2:
# -> 2297     raise LinAlgError('Incompatible dimensions')
#    2299 t, result_t = _commonType(a, b)
# ...
